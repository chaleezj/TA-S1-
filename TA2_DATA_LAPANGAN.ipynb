# %% [markdown]
# <a href="https://colab.research.google.com/github/chaleezj/TA-S1-/blob/main/TA2_DATA_LAPANGAN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn
import os
import random
import cv2
import skimage.io
import keras.backend as K
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import VGG19
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout,BatchNormalization ,Activation, Conv2D
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.callbacks import ReduceLROnPlateau, ModelCheckpoint, EarlyStopping
from tensorflow.keras.optimizers import Adam

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %% [markdown]
# ##data splitting

# %%
from sklearn.model_selection import train_test_split
import shutil

# Path ke dataset utama
dataset_path = "/content/drive/My Drive/TA/dataset_equalized"

# List semua gambar dan labelnya
all_images = []
all_labels = []

for class_name in os.listdir(dataset_path):
    class_path = os.path.join(dataset_path, class_name)
    if os.path.isdir(class_path):
        for img_name in os.listdir(class_path):
            all_images.append(os.path.join(class_path, img_name))
            all_labels.append(class_name)

# Split dataset (70% train, 20% valid, 10% test)
train_imgs, temp_imgs, train_labels, temp_labels = train_test_split(all_images, all_labels, test_size=0.3, stratify=all_labels)
valid_imgs, test_imgs, valid_labels, test_labels = train_test_split(temp_imgs, temp_labels, test_size=1/3, stratify=temp_labels)

# Fungsi untuk memindahkan file ke folder baru
def move_files(image_list, labels, destination_folder):
    for img_path, label in zip(image_list, labels):
        dest_folder = os.path.join(destination_folder, label)
        os.makedirs(dest_folder, exist_ok=True)
        shutil.copy(img_path, dest_folder)

# Tentukan folder tujuan
train_dir = "/content/drive/My Drive/TA/dataset_LAP_split/train"
valid_dir = "/content/drive/My Drive/TA/dataset_LAP_split/valid"
test_dir = "/content/drive/My Drive/TA/dataset_LAP_split/test"

# Pindahkan file sesuai split
move_files(train_imgs, train_labels, train_dir)
move_files(valid_imgs, valid_labels, valid_dir)
move_files(test_imgs, test_labels, test_dir)

print("Dataset berhasil dipisah ke folder train, valid, dan test.")
# Out:
# Dataset berhasil dipisah ke folder train, valid, dan test.

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=5,
    #width_shift_range=0.1,
    #height_shift_range=0.1,
    shear_range=0.2,
    zoom_range=0.1,
    horizontal_flip=True,
    fill_mode='nearest'
)

valid_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
    "/content/drive/My Drive/TA/dataset_LAP_split/train",
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical'
)

valid_generator = valid_datagen.flow_from_directory(
    "/content/drive/My Drive/TA/dataset_LAP_split/valid",
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical'
)

test_generator = test_datagen.flow_from_directory(
    "/content/drive/My Drive/TA/dataset_LAP_split/test",
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical'
)
# Out:
# Found 903 images belonging to 5 classes.
# Found 258 images belonging to 5 classes.
# Found 129 images belonging to 5 classes.

# %%
# Ambil satu batch dari train_generator
sample_batch, labels = next(train_generator)

# Mendapatkan daftar nama kelas dari train_generator
class_indices = train_generator.class_indices
class_names = list(class_indices.keys())  # Nama kelas sesuai urutan label

# Tentukan jumlah kelas (genus) dan jumlah sample per genus
num_classes = len(class_names)
samples_per_class = 3  # Menampilkan 3 sample per genus

# Buat figure untuk menampilkan gambar per genus
fig, axes = plt.subplots(num_classes, samples_per_class, figsize=(10, num_classes * 2))
fig.suptitle("Sampel gambar setelah di Augmentasi", fontsize=14, fontweight="bold")

# Loop untuk setiap kelas/genus
for i in range(num_classes):
    # Cari indeks gambar yang termasuk dalam kelas/genus tersebut
    class_idx = np.argmax(labels, axis=1)  # Ambil indeks kelas dari one-hot encoding
    sample_idx = np.where(class_idx == i)[0]  # Cari indeks gambar dengan kelas yang sama

    # Tambahkan judul di tengah atas per genus
    mid_col = samples_per_class // 2  # Kolom tengah untuk posisi judul
    axes[i, mid_col].set_title(class_names[i], fontsize=12, fontweight="bold", pad=10)

    for j in range(samples_per_class):  # Ambil 3 gambar per genus
        if j < len(sample_idx):  # Pastikan cukup sample tersedia
            axes[i, j].imshow(sample_batch[sample_idx[j]])  # Tampilkan gambar
        axes[i, j].axis("off")  # Hilangkan sumbu

plt.tight_layout(rect=[0, 0, 1, 0.96])  # Sesuaikan tata letak agar judul utama terlihat
plt.show()

# %%
print(train_generator.class_indices)  # Mengecek mapping label ke indeks
print(train_generator.samples)        # Mengecek jumlah sample di training set
print(valid_generator.samples)        # Mengecek jumlah sample di validation set
print(test_generator.samples)         # Mengecek jumlah sample di test set
# Out:
# {'Cattleya': 0, 'Dendrobium': 1, 'Paphiopedilum': 2, 'Phalaenopsis': 3, 'Vanda': 4}
# 903
# 258
# 129

# %%
# 4. Load Pre-trained VGG19
base_model = VGG19(weights="imagenet", include_top=False, input_shape=(224, 224, 3))

for layer in base_model.layers[-4:]:  # Buka 4 layer terakhir
    layer.trainable = True
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80134624/80134624 ━━━━━━━━━━━━━━━━━━━━ 4s 0us/step

# %%
model = Sequential([
    base_model,
    GlobalAveragePooling2D(),  # Lebih ringan!
    Dense(64, activation="relu"),
    BatchNormalization(),
    Dropout(0.3),
    Dense(5, activation="softmax")
])

# %%
from tensorflow.keras.optimizers import AdamW
from tensorflow.keras.metrics import TopKCategoricalAccuracy

model.compile(
    optimizer=AdamW(learning_rate=1e-4, weight_decay=1e-5, beta_2=0.99),
    loss="categorical_crossentropy",
    metrics=["accuracy", TopKCategoricalAccuracy(k=2, name="top_2_acc")]
)

# %%
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping, ModelCheckpoint

callbacks = [
    ReduceLROnPlateau(monitor='val_loss', factor=0.3, patience=3, min_delta=1e-4, min_lr=1e-6, verbose=1),  # Lebih stabil
    EarlyStopping(monitor='val_loss', patience=6, min_delta=1e-4, restore_best_weights=True, verbose=1),  # Cegah overfitting lebih cepat
    ModelCheckpoint("best_model.keras", monitor="val_loss",  mode="min", save_best_only=True, save_weights_only=False, verbose=1)  # Simpan model terbaik
]

# %%
history = model.fit(
    train_generator,
    steps_per_epoch=len(train_generator),  # Hemat waktu training
    epochs=30,  # Mulai dari 30 epoch, bisa ditambah jika perlu
    validation_data=valid_generator,
    validation_steps=len(valid_generator),  # Validasi lebih cepat
    callbacks=callbacks
)
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 21s/step - accuracy: 0.6330 - loss: 1.0488 - top_2_acc: 0.7854
# Epoch 1: val_loss improved from inf to 1.51388, saving model to best_model.keras
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 915s 30s/step - accuracy: 0.6388 - loss: 1.0329 - top_2_acc: 0.7893 - val_accuracy: 0.3760 - val_loss: 1.5139 - val_top_2_acc: 0.6240 - learning_rate: 1.0000e-04
# Epoch 2/30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9833 - loss: 0.0949 - top_2_acc: 0.9974
# Epoch 2: val_loss improved from 1.51388 to 0.56711, saving model to best_model.keras
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 140s 4s/step - accuracy: 0.9833 - loss: 0.0949 - top_2_acc: 0.9974 - val_accuracy: 0.8023 - val_loss: 0.5671 - val_top_2_acc: 0.9729 - learning_rate: 1.0000e-04
# Epoch 3/30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9862 - loss: 0.0803 - top_2_acc: 1.0000
# Epoch 3: val_loss improved from 0.56711 to 0.35623, saving model to best_model.keras
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 141s 4s/step - accuracy: 0.9863 - loss: 0.0798 - top_2_acc: 1.0000 - val_accuracy: 0.8992 - val_loss: 0.3562 - val_top_2_acc: 0.9302 - learning_rate: 1.0000e-04
# Epoch 4/30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9957 - loss: 0.0293 - top_2_acc: 1.0000
# Epoch 4: val_loss improved from 0.35623 to 0.34995, saving model to best_model.keras
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 140s 4s/step - accuracy: 0.9957 - loss: 0.0292 - top_2_acc: 1.0000 - val_accuracy: 0.8721 - val_loss: 0.3500 - val_top_2_acc: 0.9186 - learning_rate: 1.0000e-04
# Epoch 5/30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 1.0000 - loss: 0.0200 - top_2_acc: 1.0000
# Epoch 5: val_loss did not improve from 0.34995
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 130s 4s/step - accuracy: 1.0000 - loss: 0.0200 - top_2_acc: 1.0000 - val_accuracy: 0.7093 - val_loss: 1.0399 - val_top_2_acc: 0.9070 - learning_rate: 1.0000e-04
# Epoch 6/30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9950 - loss: 0.0294 - top_2_acc: 1.0000
# Epoch 6: val_loss improved from 0.34995 to 0.23908, saving model to best_model.keras
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 160s 5s/step - accuracy: 0.9951 - loss: 0.0292 - top_2_acc: 1.0000 - val_accuracy: 0.9264 - val_loss: 0.2391 - val_top_2_acc: 1.0000 - learning_rate: 1.0000e-04
# Epoch 7/30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 1.0000 - loss: 0.0181 - top_2_acc: 1.0000
# Epoch 7: val_loss improved from 0.23908 to 0.06562, saving model to best_model.keras
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 115s 4s/step - accuracy: 1.0000 - loss: 0.0181 - top_2_acc: 1.0000 - val_accuracy: 0.9767 - val_loss: 0.0656 - val_top_2_acc: 1.0000 - learning_rate: 1.0000e-04
# Epoch 8/30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 1.0000 - loss: 0.0161 - top_2_acc: 1.0000
# Epoch 8: val_loss improved from 0.06562 to 0.02623, saving model to best_model.keras
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 111s 4s/step - accuracy: 1.0000 - loss: 0.0161 - top_2_acc: 1.0000 - val_accuracy: 1.0000 - val_loss: 0.0262 - val_top_2_acc: 1.0000 - learning_rate: 1.0000e-04
# Epoch 9/30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9957 - loss: 0.0507 - top_2_acc: 1.0000
# Epoch 9: val_loss did not improve from 0.02623
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 112s 4s/step - accuracy: 0.9957 - loss: 0.0503 - top_2_acc: 1.0000 - val_accuracy: 0.8992 - val_loss: 0.3057 - val_top_2_acc: 0.9922 - learning_rate: 1.0000e-04
# Epoch 10/30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9959 - loss: 0.0335 - top_2_acc: 1.0000
# Epoch 10: val_loss did not improve from 0.02623
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 126s 4s/step - accuracy: 0.9959 - loss: 0.0334 - top_2_acc: 1.0000 - val_accuracy: 0.9612 - val_loss: 0.0883 - val_top_2_acc: 0.9922 - learning_rate: 1.0000e-04
# Epoch 11/30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9967 - loss: 0.0255 - top_2_acc: 1.0000
# Epoch 11: ReduceLROnPlateau reducing learning rate to 2.9999999242136255e-05.
#
# Epoch 11: val_loss did not improve from 0.02623
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 126s 4s/step - accuracy: 0.9965 - loss: 0.0261 - top_2_acc: 1.0000 - val_accuracy: 0.5969 - val_loss: 1.6988 - val_top_2_acc: 0.7054 - learning_rate: 1.0000e-04
# Epoch 12/30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9925 - loss: 0.0375 - top_2_acc: 1.0000
# Epoch 12: val_loss did not improve from 0.02623
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 163s 5s/step - accuracy: 0.9925 - loss: 0.0375 - top_2_acc: 1.0000 - val_accuracy: 0.8450 - val_loss: 0.6029 - val_top_2_acc: 0.8876 - learning_rate: 3.0000e-05
# Epoch 13/30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 1.0000 - loss: 0.0172 - top_2_acc: 1.0000
# Epoch 13: val_loss did not improve from 0.02623
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 112s 4s/step - accuracy: 1.0000 - loss: 0.0171 - top_2_acc: 1.0000 - val_accuracy: 0.9147 - val_loss: 0.2264 - val_top_2_acc: 1.0000 - learning_rate: 3.0000e-05
# Epoch 14/30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 1.0000 - loss: 0.0183 - top_2_acc: 1.0000
# Epoch 14: val_loss improved from 0.02623 to 0.00782, saving model to best_model.keras
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 145s 4s/step - accuracy: 1.0000 - loss: 0.0181 - top_2_acc: 1.0000 - val_accuracy: 1.0000 - val_loss: 0.0078 - val_top_2_acc: 1.0000 - learning_rate: 3.0000e-05
# Epoch 15/30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 1.0000 - loss: 0.0083 - top_2_acc: 1.0000
# Epoch 15: val_loss did not improve from 0.00782
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 116s 4s/step - accuracy: 1.0000 - loss: 0.0083 - top_2_acc: 1.0000 - val_accuracy: 0.9961 - val_loss: 0.0166 - val_top_2_acc: 1.0000 - learning_rate: 3.0000e-05
# Epoch 16/30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 1.0000 - loss: 0.0086 - top_2_acc: 1.0000
# Epoch 16: val_loss did not improve from 0.00782
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 145s 4s/step - accuracy: 1.0000 - loss: 0.0086 - top_2_acc: 1.0000 - val_accuracy: 1.0000 - val_loss: 0.0085 - val_top_2_acc: 1.0000 - learning_rate: 3.0000e-05
# Epoch 17/30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 1.0000 - loss: 0.0083 - top_2_acc: 1.0000
# Epoch 17: ReduceLROnPlateau reducing learning rate to 8.999999772640877e-06.
#
# Epoch 17: val_loss did not improve from 0.00782
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 156s 5s/step - accuracy: 1.0000 - loss: 0.0083 - top_2_acc: 1.0000 - val_accuracy: 0.9884 - val_loss: 0.0240 - val_top_2_acc: 1.0000 - learning_rate: 3.0000e-05
# Epoch 18/30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 1.0000 - loss: 0.0078 - top_2_acc: 1.0000
# Epoch 18: val_loss improved from 0.00782 to 0.00569, saving model to best_model.keras
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 138s 5s/step - accuracy: 1.0000 - loss: 0.0078 - top_2_acc: 1.0000 - val_accuracy: 1.0000 - val_loss: 0.0057 - val_top_2_acc: 1.0000 - learning_rate: 9.0000e-06
# Epoch 19/30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 1.0000 - loss: 0.0069 - top_2_acc: 1.0000
# Epoch 19: val_loss did not improve from 0.00569
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 118s 4s/step - accuracy: 1.0000 - loss: 0.0070 - top_2_acc: 1.0000 - val_accuracy: 1.0000 - val_loss: 0.0059 - val_top_2_acc: 1.0000 - learning_rate: 9.0000e-06
# Epoch 20/30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 1.0000 - loss: 0.0074 - top_2_acc: 1.0000
# Epoch 20: val_loss did not improve from 0.00569
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 115s 4s/step - accuracy: 1.0000 - loss: 0.0074 - top_2_acc: 1.0000 - val_accuracy: 1.0000 - val_loss: 0.0084 - val_top_2_acc: 1.0000 - learning_rate: 9.0000e-06
# Epoch 21/30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 1.0000 - loss: 0.0090 - top_2_acc: 1.0000
# Epoch 21: val_loss improved from 0.00569 to 0.00529, saving model to best_model.keras
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 115s 4s/step - accuracy: 1.0000 - loss: 0.0090 - top_2_acc: 1.0000 - val_accuracy: 1.0000 - val_loss: 0.0053 - val_top_2_acc: 1.0000 - learning_rate: 9.0000e-06
# Epoch 22/30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 1.0000 - loss: 0.0075 - top_2_acc: 1.0000
# Epoch 22: val_loss did not improve from 0.00529
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 112s 4s/step - accuracy: 1.0000 - loss: 0.0075 - top_2_acc: 1.0000 - val_accuracy: 1.0000 - val_loss: 0.0061 - val_top_2_acc: 1.0000 - learning_rate: 9.0000e-06
# Epoch 23/30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 1.0000 - loss: 0.0079 - top_2_acc: 1.0000
# Epoch 23: val_loss did not improve from 0.00529
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 117s 4s/step - accuracy: 1.0000 - loss: 0.0079 - top_2_acc: 1.0000 - val_accuracy: 0.9961 - val_loss: 0.0129 - val_top_2_acc: 1.0000 - learning_rate: 9.0000e-06
# Epoch 24/30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 1.0000 - loss: 0.0088 - top_2_acc: 1.0000
# Epoch 24: val_loss improved from 0.00529 to 0.00373, saving model to best_model.keras
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 110s 4s/step - accuracy: 1.0000 - loss: 0.0087 - top_2_acc: 1.0000 - val_accuracy: 1.0000 - val_loss: 0.0037 - val_top_2_acc: 1.0000 - learning_rate: 9.0000e-06
# Epoch 25/30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 1.0000 - loss: 0.0072 - top_2_acc: 1.0000
# Epoch 25: val_loss did not improve from 0.00373
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 142s 4s/step - accuracy: 1.0000 - loss: 0.0072 - top_2_acc: 1.0000 - val_accuracy: 0.9961 - val_loss: 0.0130 - val_top_2_acc: 1.0000 - learning_rate: 9.0000e-06
# Epoch 26/30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 1.0000 - loss: 0.0055 - top_2_acc: 1.0000
# Epoch 26: val_loss did not improve from 0.00373
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 143s 4s/step - accuracy: 1.0000 - loss: 0.0055 - top_2_acc: 1.0000 - val_accuracy: 1.0000 - val_loss: 0.0082 - val_top_2_acc: 1.0000 - learning_rate: 9.0000e-06
# Epoch 27/30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 1.0000 - loss: 0.0055 - top_2_acc: 1.0000
# Epoch 27: ReduceLROnPlateau reducing learning rate to 2.6999998226528985e-06.
#
# Epoch 27: val_loss did not improve from 0.00373
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 110s 4s/step - accuracy: 1.0000 - loss: 0.0055 - top_2_acc: 1.0000 - val_accuracy: 0.9922 - val_loss: 0.0170 - val_top_2_acc: 1.0000 - learning_rate: 9.0000e-06
# Epoch 28/30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9989 - loss: 0.0095 - top_2_acc: 0.9989
# Epoch 28: val_loss did not improve from 0.00373
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 108s 4s/step - accuracy: 0.9989 - loss: 0.0095 - top_2_acc: 0.9989 - val_accuracy: 0.9961 - val_loss: 0.0167 - val_top_2_acc: 1.0000 - learning_rate: 2.7000e-06
# Epoch 29/30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 1.0000 - loss: 0.0074 - top_2_acc: 1.0000
# Epoch 29: val_loss did not improve from 0.00373
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 113s 4s/step - accuracy: 1.0000 - loss: 0.0074 - top_2_acc: 1.0000 - val_accuracy: 0.9961 - val_loss: 0.0118 - val_top_2_acc: 1.0000 - learning_rate: 2.7000e-06
# Epoch 30/30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 1.0000 - loss: 0.0070 - top_2_acc: 1.0000
# Epoch 30: ReduceLROnPlateau reducing learning rate to 1e-06.
#
# Epoch 30: val_loss did not improve from 0.00373
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 109s 4s/step - accuracy: 1.0000 - loss: 0.0070 - top_2_acc: 1.0000 - val_accuracy: 1.0000 - val_loss: 0.0069 - val_top_2_acc: 1.0000 - learning_rate: 2.7000e-06
# Epoch 30: early stopping
# Restoring model weights from the end of the best epoch: 24.

# %% [markdown]
# ###FINE TUNING

# %%
base_model.trainable = True
for layer in base_model.layers[:-8]:  # Bekukan semua kecuali 8 layer terakhir
    layer.trainable = False

# %%
fine_tune_lr = 1e-5  # Lebih kecil


model.compile(
    optimizer=Adam(learning_rate=fine_tune_lr),
    loss="categorical_crossentropy",
    metrics=["accuracy", TopKCategoricalAccuracy(k=2)]
)

# 4. Callbacks untuk training yang lebih baik
callbacks = [
    ReduceLROnPlateau(monitor="val_loss", factor=0.5, patience=3, min_lr=1e-7),
    EarlyStopping(monitor="val_loss", patience=5, restore_best_weights=True)
]

fine_tune_epochs = 10  # Bisa ditambah jika loss masih turun

history_fine = model.fit(
    train_generator,
    steps_per_epoch=len(train_generator) // 2,
    epochs=fine_tune_epochs,
    validation_data=valid_generator,
    callbacks=callbacks
)
# Out:
# Epoch 1/10
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 87s 6s/step - accuracy: 1.0000 - loss: 0.0079 - top_k_categorical_accuracy: 1.0000 - val_accuracy: 1.0000 - val_loss: 0.0026 - val_top_k_categorical_accuracy: 1.0000 - learning_rate: 1.0000e-05
# Epoch 2/10
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - accuracy: 1.0000 - loss: 0.0069 - top_k_categorical_accuracy: 1.0000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-25-663230f6ce25> in <cell line: 0>()
#      16 fine_tune_epochs = 10  # Bisa ditambah jika loss masih turun
#      17
# ---> 18 history_fine = model.fit(
#      19     train_generator,
#      20     steps_per_epoch=len(train_generator) // 2,
#
# /usr/local/lib/python3.11/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     115         filtered_tb = None
#     116         try:
# --> 117             return fn(*args, **kwargs)
#     118         except Exception as e:
#     119             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.11/dist-packages/keras/src/backend/tensorflow/trainer.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     369                 for step, iterator in epoch_iterator:
#     370                     callbacks.on_train_batch_begin(step)
# --> 371                     logs = self.train_function(iterator)
#     372                     callbacks.on_train_batch_end(step, logs)
#     373                     if self.stop_training:
#
# /usr/local/lib/python3.11/dist-packages/keras/src/backend/tensorflow/trainer.py in function(iterator)
#     217                 iterator, (tf.data.Iterator, tf.distribute.DistributedIterator)
#     218             ):
# --> 219                 opt_outputs = multi_step_on_iterator(iterator)
#     220                 if not opt_outputs.has_value():
#     221                     raise StopIteration
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in __call__(self, *args, **kwds)
#     831
#     832       with OptionalXlaContext(self._jit_compile):
# --> 833         result = self._call(*args, **kwds)
#     834
#     835       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in _call(self, *args, **kwds)
#     876       # In this case we have not created variables on the first call. So we can
#     877       # run the first trace but we should fail if variables are created.
# --> 878       results = tracing_compilation.call_function(
#     879           args, kwds, self._variable_creation_config
#     880       )
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py in call_function(args, kwargs, tracing_options)
#     137   bound_args = function.function_type.bind(*args, **kwargs)
#     138   flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139   return function._call_flat(  # pylint: disable=protected-access
#     140       flat_inputs, captured_inputs=function.captured_inputs
#     141   )
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/eager/polymorphic_function/concrete_function.py in _call_flat(self, tensor_inputs, captured_inputs)
#    1320         and executing_eagerly):
#    1321       # No tape is watching; skip to running the function.
# -> 1322       return self._inference_function.call_preflattened(args)
#    1323     forward_backward = self._select_forward_and_backward_functions(
#    1324         args,
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py in call_preflattened(self, args)
#     214   def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215     """Calls with flattened tensor inputs and returns the structured output."""
# --> 216     flat_outputs = self.call_flat(*args)
#     217     return self.function_type.pack_output(flat_outputs)
#     218
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py in call_flat(self, *args)
#     249         with record.stop_recording():
#     250           if self._bound_context.executing_eagerly():
# --> 251             outputs = self._bound_context.call_function(
#     252                 self.name,
#     253                 list(args),
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/eager/context.py in call_function(self, name, tensor_inputs, num_outputs)
#    1681     cancellation_context = cancellation.context()
#    1682     if cancellation_context is None:
# -> 1683       outputs = execute.execute(
#    1684           name.decode("utf-8"),
#    1685           num_outputs=num_outputs,
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51   try:
#      52     ctx.ensure_initialized()
# ---> 53     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                         inputs, attrs, num_outputs)
#      55   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ vgg19 (Functional)              │ (None, 7, 7, 512)      │    20,024,384 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 512)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 64)             │        32,832 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 64)             │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 5)              │           325 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 60,173,137 (229.54 MB)
#  Trainable params: 20,057,669 (76.51 MB)
#  Non-trainable params: 128 (512.00 B)
#  Optimizer params: 40,115,340 (153.03 MB)

# %%
loss, accuracy, top_k_accuracy = model.evaluate(valid_generator)
print(f"Validation Loss: {loss:.4f}")
print(f"Validation Accuracy: {accuracy:.4f}")
print(f"Validation Top-K Accuracy: {top_k_accuracy:.4f}")
# Out:
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 22s 2s/step - accuracy: 1.0000 - loss: 0.0029 - top_2_acc: 1.0000
# Validation Loss: 0.0037
# Validation Accuracy: 1.0000
# Validation Top-K Accuracy: 1.0000

# %%
test_generator = test_datagen.flow_from_directory(
    "/content/drive/My Drive/TA/dataset_LAP_split/test",
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical',
    shuffle=False
)
print("Class indices:", test_generator.class_indices)
print("Total samples in test generator:", test_generator.samples)
# Out:
# Found 129 images belonging to 5 classes.
# Class indices: {'Cattleya': 0, 'Dendrobium': 1, 'Paphiopedilum': 2, 'Phalaenopsis': 3, 'Vanda': 4}
# Total samples in test generator: 129

# %%
# Evaluasi model dengan data testing
test_loss, test_acc, test_top_k_acc = model.evaluate(test_generator)
print(f"Test Accuracy: {test_acc:.4f}")
print(f"Test Top-2 Accuracy: {test_top_k_acc:.4f}")
print(f"Test Loss: {test_loss:.4f}")
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 68s 16s/step - accuracy: 1.0000 - loss: 0.0015 - top_2_acc: 1.0000
# Test Accuracy: 1.0000
# Test Top-2 Accuracy: 1.0000
# Test Loss: 0.0017

# %%
print("Distribusi Label Ground Truth:", np.bincount(test_generator.classes))
# Out:
# Distribusi Label Ground Truth: [26 25 25 26 27]

# %%
predictions = model.predict(test_generator)
predicted_classes = np.argmax(predictions, axis=1)
print("Distribusi Prediksi Model:", np.bincount(predicted_classes))
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step
# Distribusi Prediksi Model: [26 25 25 26 27]

# %%
import os
test_path = "/content/drive/My Drive/TA/dataset_LAP_split/test"
for class_name in os.listdir(test_path):
    print(f"{class_name}: {len(os.listdir(os.path.join(test_path, class_name)))} images")
# Out:
# Vanda: 27 images
# Dendrobium: 25 images
# Cattleya: 26 images
# Paphiopedilum: 25 images
# Phalaenopsis: 26 images

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

cm = confusion_matrix(test_generator.classes, predicted_classes)
plt.figure(figsize=(6,6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=test_generator.class_indices.keys(), yticklabels=test_generator.class_indices.keys())
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix")
plt.show()

# %%
from sklearn.metrics import classification_report
print(classification_report(test_generator.classes, predicted_classes, target_names=test_generator.class_indices.keys()))
# Out:
#                precision    recall  f1-score   support
#
#      Cattleya       1.00      1.00      1.00        26
#    Dendrobium       1.00      1.00      1.00        25
# Paphiopedilum       1.00      1.00      1.00        25
#  Phalaenopsis       1.00      1.00      1.00        26
#         Vanda       1.00      1.00      1.00        27
#
#      accuracy                           1.00       129
#     macro avg       1.00      1.00      1.00       129
#  weighted avg       1.00      1.00      1.00       129

# %%
# Konversi test_generator.classes ke array
y_true = np.array(test_generator.classes)
y_pred = np.array(predicted_classes)

# Cari indeks gambar yang salah klasifikasi
misclassified_idx = np.where(y_true != y_pred)[0]

print(f"Total salah klasifikasi: {len(misclassified_idx)}")

# Menampilkan beberapa contoh gambar yang salah
num_images = min(5, len(misclassified_idx))  # Maksimal 5 gambar
plt.figure(figsize=(15, 5))

for i, idx in enumerate(misclassified_idx[:num_images]):
    img, true_label, pred_label = test_generator.filepaths[idx], y_true[idx], y_pred[idx]

    # Load gambar dari path
    image = plt.imread(img)

    plt.subplot(1, num_images, i + 1)
    plt.imshow(image)
    plt.title(f"True: {list(test_generator.class_indices.keys())[true_label]}\nPred: {list(test_generator.class_indices.keys())[pred_label]}")
    plt.axis("off")

plt.show()
# Out:
# Total salah klasifikasi: 0

# %%
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import label_binarize
import matplotlib.pyplot as plt
import numpy as np

# Ambil jumlah kelas dari test generator
class_names = list(test_generator.class_indices.keys())
n_classes = len(class_names)

# One-hot encode label asli (ground truth)
y_test_bin = label_binarize(test_generator.classes, classes=np.arange(n_classes))

# Ambil probabilitas prediksi dari model (bukan kelas prediksi langsung)
y_pred_proba = model.predict(test_generator)

# Plot ROC Curve untuk setiap kelas
plt.figure(figsize=(8, 6))
for i in range(n_classes):
    fpr, tpr, _ = roc_curve(y_test_bin[:, i], y_pred_proba[:, i])
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, label=f"{class_names[i]} (AUC = {roc_auc:.2f})")

# Tambahkan garis diagonal sebagai referensi
plt.plot([0, 1], [0, 1], "k--", lw=2)

# Label dan judul grafik
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve - Multi-Class Classification")
plt.legend(loc="lower right")
plt.show()
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step

# %%
print("Training Accuracy:", history.history['accuracy'][-1])
print("Validation Accuracy:", history.history['val_accuracy'][-1])
# Out:
# Training Accuracy: 1.0
# Validation Accuracy: 1.0
